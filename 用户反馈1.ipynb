# %%
import pandas as pd
import numpy as np
from tblib import Frame
key_words = ["不实","虚假","不符","编","瞎话","瞎写","瞎说","错误","乱说","骗子","放屁","造谣","有病","误导","车黑","恶意","扯淡","一派胡言","不准确","不真实","胡说八道","不负责任","垃圾","吹","充值","水军","软文","无脑","恰饭","水文"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df
# Out:
#                                                content   keyword
# 0                          汽车之家可以看摩托车了，建议油耗记录里面新增摩托车记录      None
# 1    1.优化每日任务界面。任务数量，趣味性以及点击便捷度\n2.汽车币兑换增加多种额度，增加兑换...      None
# 2    个人建议，车币过期提醒需要改进一下，不能只短信提醒，而是在车币板块里，增加个容易看到的提醒，...      None
# 3    汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180...   (不实, 0)
# 4               希望可以增加用户账户中即将过期汽车币数量查询功能，以便用户更好的使用汽车币。      None
# 5    你好，提个建议。能不能在某个地方显示一下即将过期的汽车币有多少，日期是哪天。方便查询及时使用...      None
# 6                                    距上次反馈已经十天了，还是没有收到      None
# 7                                  推荐的视频根本打不开没法儿看是个什么鬼      None
# 8                                    兑换的物品已经一个多月了还没有收到      None
# 9                                  兑换车模活动，已选车模被兑完的怎么办？      None
# 10                             升级到五级了，怎么领不了车模，是不是活动是假的      None
# 11                                    升级五级怎么领不了车模，怎么解决      None
# 12                          护眼模式开启后，最下面那状态栏仍然是亮亮的，很刺眼。      None
# ...

# %%
counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假无效 不实"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容虚假、不实的评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# 汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180cm尺寸的显示兑换完了，而且，现在里边好多东西都没货了，最重要的是不实用啊，希望平台能改善下一下希望上架擦车巾大尺寸的||不实||内容虚假无效 不实
# 求求官方别再给我推荐口碑和论坛文章了 还有推荐界面的说车视频。我想多看好的文章 新闻 不是垃圾视频。||垃圾||内容虚假无效 不实
# 整个思域论坛的首页，完全被领克的水军占领了，投诉都没有用，请工作人员严格审核||水军||内容虚假无效 不实
# 揭阳广汽本田 三家店 虚假优惠  跟其他临近城市优惠幅度差距过大 且优惠不属实  比如 型格网上标优惠1.55万  实际优惠5000  严重造成客户的心理落差过大  影响消费者的正常购车参考 请严查||虚假||内容虚假无效 不实
# 要点脸吧，充值太明显了||充值||内容虚假无效 不实
# dingdangxp，车黑骚扰||车黑||内容虚假无效 不实
# 车黑，每天都在日产群影响别人，黑车||车黑||内容虚假无效 不实
# 胡说八道||胡说八道||内容虚假无效 不实
# 车黑辱骂车主||车黑||内容虚假无效 不实
# 标题党！起步13万！最高20万！你咋不说！垃圾||垃圾||内容虚假无效 不实
# 领克的水军太过于嚣张，每天都在其他车系论坛刷帖子，非常影响论坛交流，特别是在思论的论坛，希望官方能好好整顿一下其他品牌的水军||水军||内容虚假无效 不实
# 车型信息:高合HiPhi X 2021款 旗舰版4座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容虚假无效 不实
# 车型信息:高合HiPhi X 2021款 旗舰版6座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容虚假无效 不实
# 在汽车之家油卡充值，结果还没到账||充值||内容虚假无效 不实
# 垃圾软件||垃圾||内容虚假无效 不实
# 车黑辱骂车主||车黑||内容虚假无效 不实
# 把号码卖给4四店那么真牛逼，天天给我打电话卖车，这边给你卸载了？垃圾玩意||垃圾||内容虚假无效 不实
# 非本人操作被人恶意填写的联系号码||恶意||内容虚假无效 不实
# 非本人操作被人恶意填写的联系方式||恶意||内容虚假无效 不实
# 编辑后一直审核状态中||编||内容虚假无效 不实
# ...

# %%
import pandas as pd
import numpy as np
from tblib import Frame
key_words = ["不实","虚假","不符","编","瞎话","瞎写","瞎说","错误","乱说","骗子","放屁","造谣","有病","误导","车黑","恶意","扯淡","一派胡言","不准确","不真实","胡说八道","不负责任","垃圾","吹","充值","水军","软文","无脑","恰饭","水文"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword2"] = df["content"].apply(get_keywords)

df
key_words2 = ["黄色","色情","裸露","低俗"]
key_value = []
info_list = []
for word in key_words2 :
    key_value.append("")

def get_keywords2(row):
    for i in range(len(key_words2)):
        if row.find(key_words2[i]) != -1:
            return (key_words2[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword2"] = df["content"].apply(get_keywords)

df
# Out:
#                                                content keyword2
# 0                          汽车之家可以看摩托车了，建议油耗记录里面新增摩托车记录     None
# 1    1.优化每日任务界面。任务数量，趣味性以及点击便捷度\n2.汽车币兑换增加多种额度，增加兑换...     None
# 2    个人建议，车币过期提醒需要改进一下，不能只短信提醒，而是在车币板块里，增加个容易看到的提醒，...     None
# 3    汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180...  (不实, 0)
# 4               希望可以增加用户账户中即将过期汽车币数量查询功能，以便用户更好的使用汽车币。     None
# ..                                                 ...      ...
# 918                                         卡点提交 一直都不行     None
# 919  车型信息:宝马X2 2022款 sDrive25i M越野套装|参数项:感应后备厢|正确参数...     None
# 920                                           退款一直在进行中     None
# 921                                               图文不对     None
# 922  论坛的机器人没法管理一下吗？这么多话不对版的，一看就是机器人在刷评论。完全没有逛的兴趣了。再...     None
#
# [923 rows x 2 columns]

# %%
df
key_words = ["黄色","色情","裸露","低俗"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df
# Out:
#                                                content keyword
# 0                          汽车之家可以看摩托车了，建议油耗记录里面新增摩托车记录    None
# 1    1.优化每日任务界面。任务数量，趣味性以及点击便捷度\n2.汽车币兑换增加多种额度，增加兑换...    None
# 2    个人建议，车币过期提醒需要改进一下，不能只短信提醒，而是在车币板块里，增加个容易看到的提醒，...    None
# 3    汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180...    None
# 4               希望可以增加用户账户中即将过期汽车币数量查询功能，以便用户更好的使用汽车币。    None
# ..                                                 ...     ...
# 918                                         卡点提交 一直都不行    None
# 919  车型信息:宝马X2 2022款 sDrive25i M越野套装|参数项:感应后备厢|正确参数...    None
# 920                                           退款一直在进行中    None
# 921                                               图文不对    None
# 922  论坛的机器人没法管理一下吗？这么多话不对版的，一看就是机器人在刷评论。完全没有逛的兴趣了。再...    None
#
# [923 rows x 2 columns]

# %%
counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容低俗"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容低俗评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# 低俗||低俗||内容低俗
# 水军，涉及黄色内容||黄色||内容低俗
# 举报售卖推销色情服务账号||色情||内容低俗
# 传播黄色，骗子||黄色||内容低俗
# 搞色情，水军，封号||色情||内容低俗
# ...
# 内容低俗评论共有5条

# %%
counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假无效 不实"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容虚假、不实的评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'keyword'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword2"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword2"][i][0] + "||" + "内容低俗"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容低俗评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# 汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180cm尺寸的显示兑换完了，而且，现在里边好多东西都没货了，最重要的是不实用啊，希望平台能改善下一下希望上架擦车巾大尺寸的||不实||内容低俗
# 求求官方别再给我推荐口碑和论坛文章了 还有推荐界面的说车视频。我想多看好的文章 新闻 不是垃圾视频。||垃圾||内容低俗
# 整个思域论坛的首页，完全被领克的水军占领了，投诉都没有用，请工作人员严格审核||水军||内容低俗
# 揭阳广汽本田 三家店 虚假优惠  跟其他临近城市优惠幅度差距过大 且优惠不属实  比如 型格网上标优惠1.55万  实际优惠5000  严重造成客户的心理落差过大  影响消费者的正常购车参考 请严查||虚假||内容低俗
# 要点脸吧，充值太明显了||充值||内容低俗
# dingdangxp，车黑骚扰||车黑||内容低俗
# 车黑，每天都在日产群影响别人，黑车||车黑||内容低俗
# 胡说八道||胡说八道||内容低俗
# 车黑辱骂车主||车黑||内容低俗
# 标题党！起步13万！最高20万！你咋不说！垃圾||垃圾||内容低俗
# 领克的水军太过于嚣张，每天都在其他车系论坛刷帖子，非常影响论坛交流，特别是在思论的论坛，希望官方能好好整顿一下其他品牌的水军||水军||内容低俗
# 车型信息:高合HiPhi X 2021款 旗舰版4座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容低俗
# 车型信息:高合HiPhi X 2021款 旗舰版6座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容低俗
# 在汽车之家油卡充值，结果还没到账||充值||内容低俗
# 垃圾软件||垃圾||内容低俗
# 车黑辱骂车主||车黑||内容低俗
# 把号码卖给4四店那么真牛逼，天天给我打电话卖车，这边给你卸载了？垃圾玩意||垃圾||内容低俗
# 非本人操作被人恶意填写的联系号码||恶意||内容低俗
# 非本人操作被人恶意填写的联系方式||恶意||内容低俗
# 编辑后一直审核状态中||编||内容低俗
# 我是车辆的车主，我在发帖子中，里面拍了好多照片，而且里面的照片也不是在同一个地方拍的，我没有恶意评价，只是发表了自己的用车感受，以及自己的意见，以下两张照片是我的车辆||恶意||内容低俗
# ...

# %%
#============内容体验=============#
print("=================内容体验===============")
#内容虚假/无效
import pandas as pd
import numpy as np
from tblib import Frame
key_words = ["不实","虚假","不符","编","瞎话","瞎写","瞎说","错误","乱说","骗子","放屁","造谣","有病","误导","车黑","恶意","扯淡","一派胡言","不准确","不真实","胡说八道","不负责任","垃圾","吹","充值","水军","软文","无脑","恰饭","水文","博眼球","恶心"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假/无效"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容虚假/无效的评论共有{counter}条")

#内容低俗
df
key_words = ["黄色","色情","裸露","低俗"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

#主播态度/能力/声音差
df
counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "主播态度/能力/声音差"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"主播态度/能力/声音差的评论共有{counter}条")
df
key_words = ["车评人","自媒体","栏目","杂种","主播","话太多","二逼"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假无效 不实"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"主播态度/能力/声音差评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
    
        
#内容抄袭/盗图/重复
df
key_words = ["一模一样","大同小异","重复","抄袭","盗图"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容抄袭/盗图/重复"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容抄袭的评论共有{counter}条")

#内容/功能建议
df
key_words = ["希望有","最好有","建议"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容抄袭/盗图/重复"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容抄袭的评论共有{counter}条")
        
print("=================功能体验===============")
#============功能体验=============#
#电话骚扰/询价相关
df
key_words = ["暴露","泄露","接","打","电话","骚扰电话"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "电话骚扰/询价"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"电话骚扰/询价的评论共有{counter}条")
        
#禁言原因咨询/解禁申请
df
key_words = ["封禁","违规","被禁言","解封","账户异常","删帖","给删掉了"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "禁言原因咨询/解禁申请"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"禁言原因咨询/解禁申请的评论共有{counter}条")

#完成目标受阻/操作失败/不方便（高严重性）
df
key_words = ["收不到","找不到","不能关闭","全没了","都没了","在哪","不合理","数据丢失","删除不了","撤销不了","提交不了","都没了","不完善","不健全","能不能关","认证不了","失败","查不到","注销不了","查不出来","没用","没收到","能不能不要","可不可以不要","不能同步","不能认证","同步不了","加不了","关掉又会","关了又会","如何删除","不要一打开","功能没有了","填写不了","无法注册","能不能给去掉","跳出来","没找到","哪里找"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "完成目标受阻/操作失败/不方便（高严重性）"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"完成目标受阻/操作失败/不方便（高严重性）的评论共有{counter}条")

#完成目标受阻/操作失败/不方便（中严重性）
df
key_words = ["遮挡","弹窗","挂件","自动播放"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "完成目标受阻/操作失败/不方便（中严重性）"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"完成目标受阻/操作失败/不方便（中严重性）的评论共有{counter}条")

#完成目标受阻/操作失败/不方便（低严重性）
df
key_words = ["不方便","容易误碰","太小","难用","不好用","容易误触","没有之前方便","没有之前快捷"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "完成目标受阻/操作失败/不方便（低严重性）"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"完成目标受阻/操作失败/不方便（低严重性）的评论共有{counter}条")

#UI视觉问题
df
key_words = ["字太小","颜色不好看","太浅","太深"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "UI视觉问题"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"UI视觉问题的评论共有{counter}条")

#体验不一致问题
df
key_words = ["不统一","不一致","能不能一致","能不能统一"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "UI视觉问题"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"UI视觉问题的评论共有{counter}条")

print("=================功能体验===============")
#============性能体验=============#
#性能慢/卡顿/无法操作   
df
key_words = ["没反应","卡","无响应","不能进行","闪退","崩溃","加载中"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "性能慢/卡顿/无法操作 "
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"性能慢/卡顿/无法操作的评论共有{counter}条")

#页面打不开/网络问题
df
key_words = ["打不开","看不了","白屏","进不去","无法打开","无法显示","加载中"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "页面打不开/网络问题"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"页面打不开/网络问题的评论共有{counter}条")

print("=================服务/活动体验===============")
#============服务/活动体验=============#
#配送类问题 
df
key_words = ["快递","发货","物流"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "配送类问题"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"配送类问题的评论共有{counter}条")
# Out:
# =================内容体验===============
# 汽车之家签到得金币可以换东西，能不能多弄点居家用的还有车上能用的，今天刚要换那个擦车巾180cm尺寸的显示兑换完了，而且，现在里边好多东西都没货了，最重要的是不实用啊，希望平台能改善下一下希望上架擦车巾大尺寸的||不实||内容虚假/无效
# 求求官方别再给我推荐口碑和论坛文章了 还有推荐界面的说车视频。我想多看好的文章 新闻 不是垃圾视频。||垃圾||内容虚假/无效
# 整个思域论坛的首页，完全被领克的水军占领了，投诉都没有用，请工作人员严格审核||水军||内容虚假/无效
# 揭阳广汽本田 三家店 虚假优惠  跟其他临近城市优惠幅度差距过大 且优惠不属实  比如 型格网上标优惠1.55万  实际优惠5000  严重造成客户的心理落差过大  影响消费者的正常购车参考 请严查||虚假||内容虚假/无效
# 要点脸吧，充值太明显了||充值||内容虚假/无效
# 恶心||恶心||内容虚假/无效
# dingdangxp，车黑骚扰||车黑||内容虚假/无效
# 车黑，每天都在日产群影响别人，黑车||车黑||内容虚假/无效
# 胡说八道||胡说八道||内容虚假/无效
# 车黑辱骂车主||车黑||内容虚假/无效
# 标题党！起步13万！最高20万！你咋不说！垃圾||垃圾||内容虚假/无效
# 领克的水军太过于嚣张，每天都在其他车系论坛刷帖子，非常影响论坛交流，特别是在思论的论坛，希望官方能好好整顿一下其他品牌的水军||水军||内容虚假/无效
# 车型信息:高合HiPhi X 2021款 旗舰版4座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容虚假/无效
# 车型信息:高合HiPhi X 2021款 旗舰版6座|参数项:灯光特色功能|正确参数:可编程智能大灯||编||内容虚假/无效
# 在汽车之家油卡充值，结果还没到账||充值||内容虚假/无效
# 垃圾软件||垃圾||内容虚假/无效
# 这女的看着好恶心||恶心||内容虚假/无效
# 车黑辱骂车主||车黑||内容虚假/无效
# 把号码卖给4四店那么真牛逼，天天给我打电话卖车，这边给你卸载了？垃圾玩意||垃圾||内容虚假/无效
# 非本人操作被人恶意填写的联系号码||恶意||内容虚假/无效
# ...

# %%
df
key_words = ["黄色","色情","裸露","低俗"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假无效 不实"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"内容虚假、不实的评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# 低俗||低俗||内容虚假无效 不实
# 水军，涉及黄色内容||黄色||内容虚假无效 不实
# 举报售卖推销色情服务账号||色情||内容虚假无效 不实
# 传播黄色，骗子||黄色||内容虚假无效 不实
# 搞色情，水军，封号||色情||内容虚假无效 不实
# ...
# 内容虚假、不实的评论共有5条

# %%
df
key_words = ["车评人","自媒体","栏目","杂种","主播","话太多","二逼"]
key_value = []
info_list = []
for word in key_words :
    key_value.append("")

def get_keywords(row):
    for i in range(len(key_words)):
        if row.find(key_words[i]) != -1:
            return (key_words[i], i)
       
file_path = "./用户声音数量较多.csv"
df = pd.read_csv(file_path, encoding="utf-8")

df["keyword"] = df["content"].apply(get_keywords)

df

counter = 0
ans_list = []
for i in range(len(df)):
    if df["keyword"][i] != None:
        
        temp_ans = df["content"][i] + "||" + df["keyword"][i][0] + "||" + "内容虚假无效 不实"
        print(temp_ans)
        ans_list.append(temp_ans)
        counter += 1
print("================================")
print(f"主播态度/能力/声音差评论共有{counter}条")


with open("虚假评论.csv", "w", encoding="utf-8") as f:
    for i in range(len(ans_list)):
        f.write(ans_list[i] + "\n")
# Out:
# 狗日的小日本鬼子杂种车||杂种||内容虚假无效 不实
# 主播形象太差||主播||内容虚假无效 不实
# 大家拉黑这种车评人。||车评人||内容虚假无效 不实
# ...
# 主播态度/能力/声音差评论共有3条
